# %% [markdown]
# <!-- TOP OF README ANCHOR -->
# <a name="top"></a>
# <!-- PROJECT LOGO -->
# <br />
# <div align="center">
#   <p>
#     <img src="https://github.com/fangorntreabeard/cval-lib/blob/main/images/logo.jpg?raw=true" alt="Cval logo" width="155" height="155">
#   </p>
# <h3 align="center">CVAL REST API LIBRARY</h3>
#   <p align="center">
#     A library designed to interact with the REST-API cval.ai
#     <br/>
#     <b>
#       <a href="https://cval.ai">REST API docs</a>
#       ·
#       <a href="https://github.com/fangorntreabeard/cval-lib/issues">Report Bug</a>
#     </b>
#   </p>
# </div>

# %% [markdown]
# # Getting started
#
# To start using the CVAL Rest API, you need to **obtain** a **client/user API key**.
# Once you have your API key, you can use it to authenticate your requests and interact with the CVAL Rest API endpoints.
# Refer to our API documentation for detailed information on available endpoints, request formats, and response structures.

# %% [markdown]
# ## Installation

# %%
# !pip install cval-lib==0.0.2.27
# Out:
# Requirement already satisfied: cval-lib==0.0.2.27 in /usr/local/lib/python3.10/dist-packages (0.0.2.27)
# Requirement already satisfied: pydantic==1.10.9 in /usr/local/lib/python3.10/dist-packages (from cval-lib==0.0.2.27) (1.10.9)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from cval-lib==0.0.2.27) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==1.10.9->cval-lib==0.0.2.27) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->cval-lib==0.0.2.27) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->cval-lib==0.0.2.27) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->cval-lib==0.0.2.27) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->cval-lib==0.0.2.27) (2023.7.22)

# %% [markdown]
# # User guide

# %% [markdown]
# ##### Set your user_api_key

# %%
from cval_lib.connection import CVALConnection
USER_API_KEY = 'USER_API_KEY'
cval = CVALConnection(USER_API_KEY)

# %% [markdown]
# ### Dataset
#  > Within the framework of the created system, datasets are spaces in which data for machine learning is stored.
#  Creating a dataset is similar to creating a folder.

# %% [markdown]
# ##### Create dataset

# %%
ds_id = cval.dataset().create(name='on-premise-scheme-ds', description='')
print(ds_id)
# Out:
# eb28dec2-1923-4e4d-a844-9278fb8b4926

# %% [markdown]
# ##### Update dataset

# %%
ds = cval.dataset()
print(ds.update(ds_id, description='any123 string data', name='sample name'))

# :NOTE: the dataset can store the state (ds_id)
# Out:
# {'dataset_name': 'sample name', 'dataset_description': 'any123 string data', 'dataset_id': 'eb28dec2-1923-4e4d-a844-9278fb8b4926'}

# %% [markdown]
# ##### Get dataset

# %%
print(ds.get())
print(*cval.dataset().get_all(0))
# Out:
# dataset_name='sample name' dataset_description='any123 string data'
# dataset_name=None dataset_description=None dataset_id='9bc85c20-1fce-42e5-b969-c235831b8d68' dataset_name=None dataset_description=None dataset_id='6e6b11c9-0427-4435-b810-0de9b0a2b239' dataset_name=None dataset_description=None dataset_id='5749a101-42e0-4bef-918e-e53b723f5864' dataset_name=None dataset_description=None dataset_id='d878cd6a-0619-4fc2-8acb-bf3e62e0400d' dataset_name=None dataset_description=None dataset_id='fab0fa7b-00ac-4e24-b059-ce07a9706abf' dataset_name=None dataset_description=None dataset_id='87ace64a-5637-4fbe-87e8-77fbdb8a4a53' dataset_name=None dataset_description=None dataset_id='4af75617-382f-48c6-9cf8-586ca1178e9a' dataset_name=None dataset_description=None dataset_id='8a3a514a-6574-469a-863f-dfc09338293e' dataset_name=None dataset_description=None dataset_id='5c2862b0-f8ea-44ef-8cbd-59d83222702c' dataset_name=None dataset_description=None dataset_id='0fe4b8d2-aa18-4a04-9314-a81dd203649b' dataset_name=None dataset_description=None dataset_id='faafb6c0-3409-4f01-8dd0-26a83edc69bc' dataset_name=None dataset_description=None dataset_id='073da8fc-53e3-4be1-957c-1547298855b8' dataset_name=None dataset_description=None dataset_id='62f2c13f-c95f-4635-ab53-f2e9fb95deb3' dataset_name=None dataset_description=None dataset_id='1e233d8d-9daa-4348-8116-e0869be53db5' dataset_name=None dataset_description=None dataset_id='ff33c672-d8a6-4aaa-93b4-501d9a1c1b49' dataset_name=None dataset_description=None dataset_id='0c38b6e0-3a22-41ce-b7ae-8b217de00c97' dataset_name=None dataset_description=None dataset_id='5790d407-30d2-425f-af69-4e294b139897' dataset_name=None dataset_description=None dataset_id='539bbbee-7d1d-41fb-b746-7c834fb3253a' dataset_name=None dataset_description=None dataset_id='47bcc9ac-d6c6-4ed8-8dd3-ac741c32d934' dataset_name=None dataset_description=None dataset_id='ee496813-8b59-4888-9422-9be2ae18eabd' dataset_name=None dataset_description=None dataset_id='dcdc94e9-e22c-4ce1-a40c-49d1d5d2e71d' dataset_name=None dataset_description=None dataset_id='5c5f0bb2-f62d-4b3e-b09d-0a7e6b412bc8' dataset_name=None dataset_description=None dataset_id='b077be5e-6bd8-4838-a93f-33c05722c9b8' dataset_name=None dataset_description=None dataset_id='b126e88d-9d08-4d08-b01f-542341ffb224' dataset_name=None dataset_description=None dataset_id='82c0853f-7652-460d-8524-6dc3ac337ae7' dataset_name=None dataset_description=None dataset_id='4c34d8c1-ebf4-4405-95b0-0773dd140dc9' dataset_name=None dataset_description=None dataset_id='75d0e90b-b4e6-45a6-9fb4-be0cb40070e0' dataset_name=None dataset_description=None dataset_id='aa7a714c-325e-4d63-9c2c-bb89a62194da' dataset_name=None dataset_description=None dataset_id='c403a75c-8ee4-4fff-8026-4ac64bb52740' dataset_name=None dataset_description=None dataset_id='e33470a1-9872-4bc5-be26-f6d907441f06' dataset_name=None dataset_description=None dataset_id='2d8bf916-f8c6-459d-b131-98ba1acfd615' dataset_name=None dataset_description=None dataset_id='5c8d8b01-acda-48f8-bcb0-3b47f732e057' dataset_name=None dataset_description=None dataset_id='596af06b-fbc5-441d-b447-a8d04a9884d9' dataset_name=None dataset_description=None dataset_id='3780627b-9d74-4a7c-ba33-673239b1c8c7' dataset_name=None dataset_description=None dataset_id='8e622c1d-0b8e-49e5-85fa-2d31b800ee90' dataset_name=None dataset_description=None dataset_id='4f49ae89-1ba4-4f51-9310-8d904a5e1287' dataset_name=None dataset_description=None dataset_id='7df836ef-c0fa-4bfb-8a0f-f5786f3022e6' dataset_name=None dataset_description=None dataset_id='7a89a112-eaf3-47bb-b8a9-3358b51c882e' dataset_name=None dataset_description=None dataset_id='69779446-bd90-4b44-9501-0419f207b7a1' dataset_name=None dataset_description=None dataset_id='8bff35eb-48a8-48fa-a5ab-8fb76721ea5c' dataset_name=None dataset_description=None dataset_id='242a5f8d-1181-4b51-91df-601df620c600' dataset_name=None dataset_description=None dataset_id='b976656e-fdad-4682-8497-87196bf42675' dataset_name=None dataset_description=None dataset_id='6ef85637-df22-465b-92d1-2e76799b87ba' d ...

# %% [markdown]
# ### :note:
# > A further example of using the library concerns embedding. Since embedding is a large data object and the method of its creation is completely defined by the user, the embedding method works through query schemes (models).

# %% [markdown]
# ### Embeddings
# > Embeddings are vector representations of images obtained using pytorch or any other library

# %% [markdown]
# ##### Create embeddings

# %%
from random import random
import uuid
from cval_lib.connection import CVALConnection
from cval_lib.models.embedding import EmbeddingModel, FrameEmbeddingModel

embeddings = tuple(
        map(
            lambda x: FrameEmbeddingModel(
                frame_id=uuid.uuid4().hex,
                embeddings=[
                    EmbeddingModel(embedding_id=uuid.uuid4().hex, embedding=list(map(lambda x: random(), range(500))))]
            ),
            range(100)
        )
    )

print(embeddings)
# Out:
# (FrameEmbeddingModel(frame_id='c3650f69821843e5b92b3301594daf7a', embeddings=[EmbeddingModel(embedding_id='fc832ce1fead4eb8b0a56ed992cd7eb6', embedding=[0.719192973959289, 0.19199759253516757, 0.4681776430939304, 0.5053458521212363, 0.7834515344506223, 0.9639092724360117, 0.012543304368498265, 0.03463089100455674, 0.14858427348169223, 0.5326941051139692, 0.34802678671420173, 0.8799326775292399, 0.31942909106913675, 0.8021421055754204, 0.47516369199492203, 0.9807809870902118, 0.6733691074308042, 0.16551850445365401, 0.324760968627278, 0.7384523103201399, 0.17168772716114644, 0.46066819812460646, 0.7775846031332269, 0.14115606843957718, 0.9892353467908306, 0.29788363062658385, 0.2571856961072485, 0.19674516601382364, 0.7939304305154282, 0.5463338933877397, 0.04261256217570841, 0.16793852779886953, 0.2279468548450978, 0.4140518240843635, 0.46126978528474527, 0.25023876379017906, 0.8581607604279333, 0.41273961714143337, 0.895437687656651, 0.8798990283859308, 0.5914245685506562, 0.08437775654015467, 0.10306118731548886, 0.003806703702603942, 0.6159626518926028, 0.7766535549012827, 0.9132527933314077, 0.792409329571855, 0.6920174402658053, 0.5715514681357649, 0.13298453350489126, 0.49096520294523316, 0.547005657207764, 0.406965468122653, 0.07216539867516614, 0.7211812078633143, 0.3044886875409458, 0.46477870615485406, 0.6920808672272323, 0.49320384180327104, 0.2838626978748009, 0.7554834141577728, 0.4290979055030574, 0.32276130477965703, 0.5014773823500042, 0.7564648983355237, 0.4785471125124897, 0.5172303726735602, 0.8094513515798174, 0.4568940237217799, 0.8528329330184341, 0.17097957668689134, 0.4221110160117948, 0.47469553288070354, 0.9520246779048287, 0.5168690603289482, 0.09273813341585757, 0.30994847104398693, 0.9467422385839537, 0.6430231991592247, 0.4062906158896792, 0.7
# frames_quantity=100 frames=[FrameEmbeddingResponseModel(frame_id='d9831452f5314124872e37f3816d0f3f', embeddings_quantity=1, embeddings=['a69d92dd07e9448f89ae5fe31d5e5a79']), FrameEmbeddingResponseModel(frame_id='58389a159f2741c99c2267a06c35b230', embeddings_quantity=1, embeddings=['9dc7b9efe90a4c67b30159b62df3c9be']), FrameEmbeddingResponseModel(frame_id='f2c69cea6794472a92a6d1f80f3381d6', embeddings_quantity=1, embeddings=['d81526b79c34438da3f6208af26138e6']), FrameEmbeddingResponseModel(frame_id='70e7682f568e463889c8e97a3a7f68ce', embeddings_quantity=1, embeddings=['88acd8e1bba64e49b52b699d2be4728b']), FrameEmbeddingResponseModel(frame_id='c3650f69821843e5b92b3301594daf7a', embeddings_quantity=1, embeddings=['fc832ce1fead4eb8b0a56ed992cd7eb6']), FrameEmbeddingResponseModel(frame_id='991e4ffc45ab486aadbb4eb3a6864cff', embeddings_quantity=1, embeddings=['62fcc200611c4af7a5c88b7394ba2cfa']), FrameEmbeddingResponseModel(frame_id='126275f9310347b9b641c0100172d9c0', embeddings_quantity=1, embeddings=['43aa4daf94eb4342a8dc68a14400637e']), FrameEmbeddingResponseModel(frame_id='acdce5d9bdeb4ef2badf4d78440f7861', embeddings_quantity=1, embeddings=['056611ff4964470083baca685a9e6bb4']), FrameEmbeddingResponseModel(frame_id='769f6bd5925f4eeea1951269d8a09ad5', embeddings_quantity=1, embeddings=['b3a90d5bd23946409eb91246dbca9ad8']), FrameEmbeddingResponseModel(frame_id='eae2b93caf7547c89ac929ced5fa96d8', embeddings_quantity=1, embeddings=['59d0777b522145918caf807336fe0920']), FrameEmbeddingResponseModel(frame_id='0cfe72dc42d94f3abefd9befe75cd7cc', embeddings_quantity=1, embeddings=['d9f7818e087a4373a47646ca726fc171']), FrameEmbeddingResponseModel(frame_id='b0ebb948d2f8441bb800282d5cc6da59', embeddings_quantity=1, embeddings=['acc9a5c22dc440a7a782798da43abcd5']), FrameEmbeddingResponseModel(frame_id='60450df864894e2eb0229ca4abbe4f27', embeddings_quantity=1, embeddings=['9e8a2d28c26248d794e04778b11d6a2a']), FrameEmbeddingResponseModel(frame_id='fcb67acc89c84082b46cb30bf7c3326a', embeddings_quantity=1, embeddings=['d8484e966fe74aaeb4b964a88ba8cade']), FrameEmbeddingResponseModel(frame_id='461646d58b7a45189cb1159354de672e', embeddings_quantity=1, embeddings=['702cb3e71f2346998c3b570b10a36d5a']), FrameEmbeddingResponseModel(frame_id='badd6b19e0b84c659715b1512e8bd5ec', embeddings_quantity=1, embeddings=['4ddb01ef66a445b9a928dc2ac1f6e57e']), FrameEmbeddingResponseModel(frame_id='45bdcfb6ad04472b83da07d6d12e1bc0', embeddings_quantity=1, embeddings=['645ecc8c299245fb93650710c714c955']), FrameEmbeddingResponseModel(frame_id='20478a4c3c6040fd81968fca546fa21d', embeddings_quantity=1, embeddings=['3c612cc123f245dfaf2533394c2fa50a']), FrameEmbeddingResponseModel(frame_id='3d115f3f6b914a70ad173abe317706a7', embeddings_quantity=1, embeddings=['6baaaeecb4c74d889bc53c9b8f924e55']), FrameEmbeddingResponseModel(frame_id='ec966346b86745df8598f9f33d106fdb', embeddings_quantity=1, embeddings=['88e39f36c24849a4b44a1b135e70f208']), FrameEmbeddingResponseModel(frame_id='f637bd75715a412c9abb20dbb9a4ec09', embeddings_quantity=1, embeddings=['8a13082dd8f2457abe56736ce7db0ec5']), FrameEmbeddingResponseModel(frame_id='a27b33a7f317440ab6b448514df9e962', embeddings_quantity=1, embeddings=['3d88d7216d79419591343b4d9e7feb9d']), FrameEmbeddingResponseModel(frame_id='9f6f3c6e07774f9097498594669084c7', embeddings_quantity=1, embeddings=['36ccc1b4f80644bd9581397e9882e394']), FrameEmbeddingResponseModel(frame_id='8056819eadf8470ba90811b574de2ae4', embeddings_quantity=1, embeddings=['5c78a3e0ca654fc48276e17b32d11a1c']), FrameEmbeddingResponseModel(frame_id='2c8705bc14044b6eba9eb766ad314176', embeddings_quantity=1, embeddings=['92036a41bdd647ba922d4638333138fb']), FrameEmbeddingResponseModel(frame_id='a418831b67ad4e259b530337d1b4db22', embeddings_quantity=1, embeddings=['5db7924aee6e42bbb979a0d8f1ae9c74']), FrameEmbeddingResponseModel(frame_id='6ac1a00e6b544a5b85a48d2195769c14', embeddings_quantity=1, embeddings=['83d44d9aa72044f99699db24c8d8e322']), FrameEmbeddingResponseModel(fr ...

# %% [markdown]
# ### :note:
# > The following example is used to invoke active learning

# %% [markdown]
# ### Active learning

# %% [markdown]
# ##### Get predictions data

# %%
from random import random
import uuid
from cval_lib.models.detection import BBoxScores, FramePrediction

# :NOTE: example only
frames_predictions = list(
    map(
        lambda x: FramePrediction(
            frame_id=str(uuid.uuid4().hex),
            predictions=list(
                map(lambda x: BBoxScores(category_id=1, score=random()), range(10)))
        ),
        range(10)
    )
)
print(frames_predictions)
# Out:
# [FramePrediction(frame_id='e825acbacafb4269889336976db0f148', predictions=[BBoxScores(category_id='1', score=0.7816575263989136, embedding_id=None), BBoxScores(category_id='1', score=0.8993917350419026, embedding_id=None), BBoxScores(category_id='1', score=0.79980126637699, embedding_id=None), BBoxScores(category_id='1', score=0.4799045300307191, embedding_id=None), BBoxScores(category_id='1', score=0.48295548779121145, embedding_id=None), BBoxScores(category_id='1', score=0.01754114337704593, embedding_id=None), BBoxScores(category_id='1', score=0.23978973575483653, embedding_id=None), BBoxScores(category_id='1', score=0.8221639051441663, embedding_id=None), BBoxScores(category_id='1', score=0.15276448537954823, embedding_id=None), BBoxScores(category_id='1', score=0.6378096133241542, embedding_id=None)]), FramePrediction(frame_id='3c2c5f90b55f41cb9d32b5daad6a0d2c', predictions=[BBoxScores(category_id='1', score=0.8503262164507673, embedding_id=None), BBoxScores(category_id='1', score=0.5546548090560224, embedding_id=None), BBoxScores(category_id='1', score=0.6928379295044926, embedding_id=None), BBoxScores(category_id='1', score=0.7257221906731159, embedding_id=None), BBoxScores(category_id='1', score=0.18442708867633317, embedding_id=None), BBoxScores(category_id='1', score=0.4075246372218425, embedding_id=None), BBoxScores(category_id='1', score=0.11667944040617251, embedding_id=None), BBoxScores(category_id='1', score=0.6546413769128342, embedding_id=None), BBoxScores(category_id='1', score=0.8618626341909997, embedding_id=None), BBoxScores(category_id='1', score=0.4161963839719237, embedding_id=None)]), FramePrediction(frame_id='93d316b47ba44df290522b46d4ceb129', predictions=[BBoxScores(category_id='1', score=0.34178616261226114, embedding_id=None), BBoxScores(category_id='1', score=0.7524140925982324, embedding_id=None), BBoxScores(category_id='1', score=0.6840338321403908, embedding_id=None), BBoxScores(category_id='1', score=0.7564632686167289, embedding_id=None), BBoxScores(category_id='1', score=0.5475106031314532, embedding_id=None), BBoxScores(category_id='1', score=0.9246220569759258, embedding_id=None), BBoxScores(category_id='1', score=0.3632417861879971, embedding_id=None), BBoxScores(category_id='1', score=0.9662771508994086, embedding_id=None), BBoxScores(category_id='1', score=0.7199363076085108, embedding_id=None), BBoxScores(category_id='1', score=0.709475296870464, embedding_id=None)]), FramePrediction(frame_id='32efd1fb04224e9097e77f2da8053cff', predictions=[BBoxScores(category_id='1', score=0.721648337763129, embedding_id=None), BBoxScores(category_id='1', score=0.13757504390144137, embedding_id=None), BBoxScores(category_id='1', score=0.019823264779897487, embedding_id=None), BBoxScores(category_id='1', score=0.823207194785528, embedding_id=None), BBoxScores(category_id='1', score=0.7222270151116422, embedding_id=None), BBoxScores(category_id='1', score=0.5421899967277279, embedding_id=None), BBoxScores(category_id='1', score=0.8844793816014149, embedding_id=None), BBoxScores(category_id='1', score=0.3689879422938862, embedding_id=None), BBoxScores(category_id='1', score=0.685374835740938, embedding_id=None), BBoxScores(category_id='1', score=0.9914957751518854, embedding_id=None)]), FramePrediction(frame_id='049baf2728f147dca16ee970a2d7947a', predictions=[BBoxScores(category_id='1', score=0.14283765529582848, embedding_id=None), BBoxScores(category_id='1', score=0.05515291403729872, embedding_id=None), BBoxScores(category_id='1', score=0.9602621653648131, embedding_id=None), BBoxScores(category_id='1', score=0.4384295653635314, embedding_id=None), BBoxScores(category_id='1', score=0.5541606552905444, embedding_id=None), BBoxScores(category_id='1', score=0.787384342007888, embedding_id=None), BBoxScores(category_id='1', score=0.6343789839080769, embedding_id=None), BBoxScores(category_id='1', score=0.21270689250325858, embedding_id=None), BBoxScores(category_id='1', score=0.9515163712979465, embedding ...

# %% [markdown]
# ##### Construct config

# %%
from cval_lib.models.detection import DetectionSamplingOnPremise

request = DetectionSamplingOnPremise(
 num_of_samples=200,
 bbox_selection_policy='min',
 selection_strategy='margin',
 sort_strategy='ascending',
 frames=frames_predictions,
)

# %% [markdown]
# ##### Run active learning

# %%
emb = cval.detection()
print(emb.on_premise_sampling(request))
# Out:
# task_id='a2e4824e-1a4c-4a8e-bd42-d2649f7e6778' dataset_id=None time_start=1690493668.269995 time_end=1690493668.2699943 type_of_task='detection' action='sampling' weights=None result=['8a8cfbf3d7e544cca17166d27cf3546e', '32efd1fb04224e9097e77f2da8053cff', '5e5b8343bee34aaa8a79751af6ba55db', 'e825acbacafb4269889336976db0f148', '93d316b47ba44df290522b46d4ceb129', '049baf2728f147dca16ee970a2d7947a', 'beef6fa1fb5f48539db1dd55187f911b', 'b10a864aedce45ca8aabcaef84b14a4d', '854204035f304b59b3dc5683a48fce23', '3c2c5f90b55f41cb9d32b5daad6a0d2c']

# %% [markdown]
# ###:note:
# > The following method is most relevant when we are dealing with long-term tasks and, accordingly, with asynchronous interaction.

# %% [markdown]
# ### Polling
# > refers to actively sampling the status of an external device by a client program as a synchronous activity.

# %%
import uuid
from random import random, randint
from time import sleep

frames_predictions = list(
        map(
            lambda x: FramePrediction(
                frame_id=str(uuid.uuid4().hex),
                predictions=list(map(lambda _: BBoxScores(category_id=randint(0, 3), score=random()), range(20)))
            ),
            range(10000)
        )
    )

request = DetectionSamplingOnPremise(
        num_of_samples=200,
        bbox_selection_policy='min',
        selection_strategy='margin',
        sort_strategy='ascending',
        frames=frames_predictions,
    )

emb = cval.detection()
print(emb.on_premise_sampling(request))

result = None
sleep_sec = 1
while result is None:
    result = emb.result.get().result
    print(f'Polling... {sleep_sec} s')
    sleep(sleep_sec)
    sleep_sec *= 2
print(result)
# Out:
# task_id='3cc10a61-c03a-478d-be03-3d06cf30bed5' dataset_id=None time_start=1690494445.4152808 time_end=None type_of_task='detection' action='sampling' weights=None result=None
# Polling... 1 s
# Polling... 2 s
# ['940e7ea54eb44e0cad4b6f88f6a83b10', '5455dda4f1334e94a32fb3c656d34f94', '016e2b160ec2494a845be3d2aa37ed4c', '77d74953e84d4f44b5c59a4b4dd534cb', '7033cf0258f94afe8027f1fcd838e328', '1bff54fb21fe440099a1565fa305e2e7', '05f0142146a045e09065b6b04ce11916', '96bcb5dc3f6b4b3895ce6669558b2a80', 'fe0bb91c1b2d4e4fa60c56a21ffbd732', 'b2722fd7d92a4fc1ae52391f622966c9', '45344c72b8954a8aaff49255a042d1bd', '76a111e8b61e4ba3ba846ea76b3a5be3', '2f2174e487174259968b8c8e771ffd9c', 'a96a2cac3b284f70bd2979a6de2979ab', '925d87f030f74b58a527437bb219d000', 'becf523af65f430989e751253418c355', '031cc30d14ee446b9297c9646b4d7a87', '24d5f346840842f0be655bf87d04020a', '9a29041bd6dc4397b8dc28ac7c6d0a5a', '637aebff372f475ea427426bd818ff90', '0ec569c132ce48358cf2de738ac9b2c6', '01bd91f3992a451cad5a709ce572c51c', '0d3c937ca31e469cb9dda4e8
163c58d4e96bdb3cda840fd5e61', 'e7581cecf95c45c1bb3eed537f335f44', '98d9be1f61594838af406116fe4ab94a', 'bbff43a19d974034a9d0bb851c891fa9', '719515707afd460dbe32fbfe0dd629cd', '6f319c1730b443dc84e984cc54d840e0', 'af4d9779f4ee4e1d88c955ab600c940c', 'adf48afc9ccf4820ac44d0948c0c378f', 'f3bdee6b41194e0e97d8f9283258c845', '9a57d69cf17749e49fdaa2adc5141980', 'ee2c3da93f964dcd96106bc022d9acc5', '24be5b6101d34576aaae269030c069f8', '0afd810ac1964b08a14ec846debfbb74', '85ab0874570f4c4d846fe35a50970d77', 'ad6ded6a6b2642fa9ed79b7d31819ba6', '629bc6d882514e108d0f75cf2873ea48', '838db5b6f673485eba9e22622d72f096', '2fcbe571bf6247b5968591d2cba644e9', 'c049729607e64106b6028941e6254318', '84dbed7f925b49aba33e515904ef1134', '917cf174c6464af7bc4bc4c81a3748c3', '368bc58c97b84931ac7bd88480d09e6a', '8001f732969043219a83bba312e6802f', 'c3d2166a5ac149c5ad5b9fbd92bf5c7f', '05 ...

# %% [markdown]
# ### Clustering. Embedding usage

# %%
import math
import random
import uuid
from time import sleep

from cval_lib.connection import CVALConnection
from cval_lib.models.detection import DetectionSamplingOnPremise
from cval_lib.models.embedding import FrameEmbeddingModel, EmbeddingModel


# :note: Generate embeddings and scores, for example -- there is random generator:

def get_frames(num_images: int, num_bboxes: int, emb_sz: int, categ_sz: int):
    _predictions = []
    _embeddings = []
    for i in range(num_images):
        emb = []
        scr = []
        image_name = str(uuid.uuid4().hex)
        for boxs in range(num_bboxes):
            _id = uuid.uuid4().hex
            scr.append(
                {
                    "embedding_id": _id,
                    "score": math.cos(random.random()),
                    "category_id": random.randint(0, categ_sz),
                },
            )
            emb.append(
                EmbeddingModel(**{
                    "embedding_id": _id,
                    "embedding": list(map(lambda x: random.random(), range(emb_sz))),
                })
            )

        _embeddings.append(
            FrameEmbeddingModel(**{
                "frame_id": image_name,
                "embeddings": emb,
            }),
        )
        _predictions.append(
            {
                "frame_id": image_name,
                "predictions": scr,
            },
        )
    return _embeddings, _predictions


embeddings, predictions = get_frames(100, 1, 500, 1)
ds_id = cval.dataset().create(name='asd', description='1a2')
print(ds_id)
print(cval.embedding(dataset_id=ds_id, part_of_dataset='training').upload_many(embeddings))

# :note: create config and get task_id

task_id = cval.detection().on_premise_sampling(
    DetectionSamplingOnPremise(
        num_of_samples=20,
        dataset_id=ds_id,
        selection_strategy='clustering',
        frames=predictions,
        bbox_selection_policy='sum',
    )
).task_id

result = None
sleep_sec = 1

# :note: start long-polling

while result is None:
    result = cval.result().get(task_id).result
    print(f'Polling... {sleep_sec}')
    sleep(sleep_sec)
    sleep_sec *= 2

print(result)
# Out:
# dcd90a12-efd1-408f-a773-a95af640b367
# frames_quantity=100 frames=[FrameEmbeddingResponseModel(frame_id='700bb570f3ad413dafc814ceceb6dc09', embeddings_quantity=1, embeddings=['2af55faaeb4d4bf0a585c563f0c4ca3f']), FrameEmbeddingResponseModel(frame_id='0070c97e06b24b7e928dcbbfd40dc52e', embeddings_quantity=1, embeddings=['711e26ff6e324e2f910ebbe688b621f4']), FrameEmbeddingResponseModel(frame_id='c3c330860131483993581d926669572a', embeddings_quantity=1, embeddings=['208b8e0af80b4f0e93bc1ae3df41ad7c']), FrameEmbeddingResponseModel(frame_id='5ec279ab4e9c424cb879fd4c02974a4c', embeddings_quantity=1, embeddings=['59e15729b4c14ce4b8cb03505eb22203']), FrameEmbeddingResponseModel(frame_id='2fefd6c0ce284665b4ed407db2bb4b39', embeddings_quantity=1, embeddings=['dc475c994f914c059f48dcf05d252fc5']), FrameEmbeddingResponseModel(frame_id='b008c69702ec44c487e25c88c241d3b3', embeddings_quantity=1, embeddings=['1424e8b62abd422687598805f12fb40e']), FrameEmbeddingResponseModel(frame_id='67c48b279151487bafc6f11811d9f201', embeddings_quantity=1, embeddings=['5452a953ea4d4ecdb2ce00cd8d04aa30']), FrameEmbeddingResponseModel(frame_id='4376844c8dc84f10a259a89ceea7ffd2', embeddings_quantity=1, embeddings=['7c21ff08c2a24929ac5184792995710d']), FrameEmbeddingResponseModel(frame_id='89035db5056d4620a4993856cfc75698', embeddings_quantity=1, embeddings=['a85735e67aff4bfcbd65a3b17c93a1c4']), FrameEmbeddingResponseModel(frame_id='c26fb068441d435e8ed917f34f6368e7', embeddings_quantity=1, embeddings=['7eb599e066fa4a76ae242066bda9f46f']), FrameEmbeddingResponseModel(frame_id='b8223b4d2a2248f98885724279ff0840', embeddings_quantity=1, embeddings=['216580424f544dc19524a66a954e1681']), FrameEmbeddingResponseModel(frame_id='6c4260bbb7754812b7e5fde9b1a79abe', embeddings_quantity=1, embeddings=['fac457d5416046e69b6db68d2c56794e']), FrameEmbeddingResponseModel(frame_id='5859521ecae3429ab5ed639d8836dc8b', embeddings_quantity=1, embeddings=['8371057d8c694e6991006119d9a5870b']), FrameEmbeddingResponseModel(frame_id='5e6e6f54e02547fab7e00990177c6e8b', embeddings_quantity=1, embeddings=['4d8c5bda870e45509836b4fc8ffe6177']), FrameEmbeddingResponseModel(frame_id='7b5c426795374b6b823e5549e6c0f930', embeddings_quantity=1, embeddings=['f4cdb71aa9ea407c963a95297b1d3aab']), FrameEmbeddingResponseModel(frame_id='f64b855bcf304c8bac38388ccdb0d2ab', embeddings_quantity=1, embeddings=['94b74928fbd44823aa1549b33ebdef0f']), FrameEmbeddingResponseModel(frame_id='57b87b7e1a164cb8819c0c2cb0bfdc2f', embeddings_quantity=1, embeddings=['f41233b98b674607b0689e979769ef22']), FrameEmbeddingResponseModel(frame_id='e15cda5eb8fb49d5821c8bdef3202eb9', embeddings_quantity=1, embeddings=['71aa934405694192951d489c47d5e577']), FrameEmbeddingResponseModel(frame_id='3a32ca213021401dab2de72761167670', embeddings_quantity=1, embeddings=['1006de61e7e64785af12bb2e149b55eb']), FrameEmbeddingResponseModel(frame_id='a0043f036d454f48ab1dbf131ef2d914', embeddings_quantity=1, embeddings=['9087f6f9e9af42fdb9f22f0f91e37457']), FrameEmbeddingResponseModel(frame_id='3523a5b167aa4b1baef5b18e475ecab3', embeddings_quantity=1, embeddings=['c6b32e8f08f246b8868b3ce5a7e73866']), FrameEmbeddingResponseModel(frame_id='dd578f3a72b54b77965e24e68ebb27c5', embeddings_quantity=1, embeddings=['7ef49d76d27640b0b523f4349c142698']), FrameEmbeddingResponseModel(frame_id='92b5e312fdfc40f995042be14445cfce', embeddings_quantity=1, embeddings=['3754e29d89154721abcc77c49a23f1bf']), FrameEmbeddingResponseModel(frame_id='bfb8aa61526747d9a6da763b01835949', embeddings_quantity=1, embeddings=['68902a319c814bf8a4d681b507c10c0b']), FrameEmbeddingResponseModel(frame_id='d998f9669cf94271939f42a79cca6a4b', embeddings_quantity=1, embeddings=['9c6f5130695e4224bd042a10af9c382f']), FrameEmbeddingResponseModel(frame_id='a3731dbc1b5b4afba971cff69c21db4c', embeddings_quantity=1, embeddings=['326cf5df8a864225983795483caf1e42']), FrameEmbeddingResponseModel(frame_id='1c719b472fb9417c9f869567617cdd89', embeddings_quantity=1, embeddings=['e0ceee18fb894a949765105ffbf7ab73']), FrameEmbeddingResponseModel(fr ...
# Polling... 1
# Polling... 2
# Polling... 4
# Polling... 8
# ['04cddeb741f94076bbde6382c0b19c74', '103b2be799c94afebebb72b6815c7d44', '15e17641a27244a3a0b31fb0c2cda316', '4564014db3f2401eb150c60caeb84aa5', '500032f1d6e548ea9a2da4bb9fc27886', '51796b11cf6d4f1f824bca9abb3281c4', '67c48b279151487bafc6f11811d9f201', '6c4260bbb7754812b7e5fde9b1a79abe', '700bb570f3ad413dafc814ceceb6dc09', '7c6f76b4479a4da5b976356f3870e730', '8778e40547fa42fe880711cf762af7fe', '8ee025c85bad4953ac856b89a0cdb3d5', '910e2748331f465ca683b9d0cf280c4d', 'a3731dbc1b5b4afba971cff69c21db4c', 'a471e6ea49d94ace9e9c6ff8177ea9bf', 'b008c69702ec44c487e25c88c241d3b3', 'b8223b4d2a2248f98885724279ff0840', 'cfa2576ad30e4fdcbe3ab93028ecc11e', 'd998f9669cf94271939f42a79cca6a4b', 'f964bb9b6128425d98f53cdfdaec7a21']

# %% [markdown]
# ### Method combination

# %%
import copy
import json
import math
import random
import uuid
from pprint import pprint
from time import sleep

from cval_lib.connection import CVALConnection
from cval_lib.models.detection import DetectionSamplingOnPremise
from cval_lib.models.embedding import FrameEmbeddingModel, EmbeddingModel

# :note: score generator

def get_scores(num_images: int, num_bboxes: int, categ_sz: int):
    _predictions = []
    for i in range(num_images):
        scr = []
        image_name = str(uuid.uuid4().hex)
        for boxs in range(num_bboxes):
            _id = uuid.uuid4().hex
            scr.append(
                {
                    'embedding_id': uuid.uuid4().hex,
                    "score": math.cos(random.random()),
                    "category_id": random.randint(0, categ_sz),
                },
            )
        _predictions.append(
            {
                "frame_id": image_name,
                "predictions": scr,
            },
        )
    return _predictions

# :note: embeddings generator for images

def get_embeddings(_frames: list[str], _predictions, emb_sz=500):
    _embeddings = []
    for i in _frames:
        for j in _predictions:
            if i == j.get('frame_id'):
                emb = [
                    EmbeddingModel(**{
                        "embedding_id": k.get('embedding_id'),
                        "embedding": list(map(lambda x: random.random(), range(emb_sz))),
                    }) for k in j.get('predictions')
                ]

                _embeddings.append(
                    FrameEmbeddingModel(**{
                        "frame_id": j.get('frame_id'),
                        "embeddings": emb,
                    }),
                )
    return _embeddings

# :note: 500 detections with 14 scores, 2 categories

predictions = get_scores(500, 14, 1)

ds_id = cval.dataset().create(name='asd', description='1a2')

task_id = cval.detection().on_premise_sampling(
    DetectionSamplingOnPremise(
        num_of_samples=20,
        dataset_id=ds_id,
        selection_strategy='entropy',
        sort_strategy='ascending',
        bbox_selection_policy='sum',
        frames=predictions,
    )
).task_id

result = None
sleep_sec = 1

# :note: start polling for first sample

while result is None:
    result = cval.result().get(task_id).result
    print(f'Polling... {sleep_sec}')
    sleep(sleep_sec)
    sleep_sec *= 2

pprint(result)

# :note: upload embedding for first sample

cval.embedding(dataset_id=ds_id, part_of_dataset='training').upload_many(get_embeddings(result, predictions))

# :note: start polling for second sample

task_id = cval.detection().on_premise_sampling(
    DetectionSamplingOnPremise(
        num_of_samples=2,
        # :note: requires: len(first_sample) > len(second_sample)
        dataset_id=ds_id,
        selection_strategy='clustering',
        frames=list(filter(lambda x: x.get('frame_id') in result, predictions)),
    )
).task_id


result = None
sleep_sec = 1

while result is None:
    result = cval.result().get(task_id).result
    print(f'Polling... {sleep_sec}')
    sleep(sleep_sec)
    sleep_sec *= 2

pprint(result)
# Out:
# Polling... 1
# ['342b4f7c36c548ee9b6b3fe51803c56a',
#  '60983453e6e2457c9ac64edf3675c66c',
#  '32d2a9ae05b0498eadf106f4943a2a53',
#  '5e2f87d8caaf4b198eee0b34eb723b58',
#  'b0804a8eff1d4bf1ac5f4881bc62a78c',
#  'bb153859c0474f4ebda65351fa0a9f89',
#  'b481ede0b50d4a61b7ba4e13445fbd31',
#  'e5c50009fee245ebaad02ad67da61ab6',
#  'f80551f614ae47b69735830a4bcd1a51',
#  'bfb14e3c0a434f4d936c0bf2a7dd7490',
#  '8a73d85b69ab40e699a17760b3e8944e',
#  '0bceaa6c9e054a13a6a111fd57949196',
#  '36bb6bffb41545f699ecfb859ed2eaf4',
#  '6ecb29071cd14c24905484b8cf62bfd6',
#  '745ea57a905d411cae9552a02a3c21aa',
#  '5d2b69540065495999916bf3478da18b',
#  '82009fa9da9c4b4b9a9d0072a100080d',
#  'b5623e4bfa2543be80b1b0fc3a359401',
#  '07377213c0f14d63af7b5e1dcd0873c7',
#  'e57deb74171146e19dc7b119c6e00718']
# Polling... 1
# Polling... 2
# ['bfb14e3c0a434f4d936c0bf2a7dd7490', 'e5c50009fee245ebaad02ad67da61ab6']
