# %% [markdown]
# <!-- TOP OF README ANCHOR -->
# <a name="top"></a>
# <!-- PROJECT LOGO -->
# <br />
# <div align="center">
#   <p>
#     <img src="https://github.com/fangorntreabeard/cval-lib/blob/main/logo/logo.jpg?raw=true" alt="Cval logo" width="155" height="155">
#   </p>
# <h3 align="center">CVAL REST API LIBRARY</h3>
#   <p align="center">
#     A library designed to interact with the REST-API cval.ai
#     <br/>
#     <b>
#       <a href="https://cval.ai">REST API docs</a>
#       ·
#       <a href="https://github.com/fangorntreabeard/cval-lib/issues">Report Bug</a>
#     </b>
#   </p>
# </div>

# %% [markdown]
# # Getting started
#
# To start using the CVAL Rest API, you need to **obtain** a **client/user API key**.
# Once you have your API key, you can use it to authenticate your requests and interact with the CVAL Rest API endpoints.
# Refer to our API documentation for detailed information on available endpoints, request formats, and response structures.

# %% [markdown]
# ## Installation

# %%
# !pip install cval-lib
# Out:
# Collecting cval-lib
#   Downloading cval-lib-0.0.2.6.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from cval-lib) (1.10.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from cval-lib) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->cval-lib) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->cval-lib) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->cval-lib) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->cval-lib) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->cval-lib) (3.4)
# Building wheels for collected packages: cval-lib
#   Building wheel for cval-lib (setup.py) ... done
#   Created wheel for cval-lib: filename=cval_lib-0.0.2.6-py3-none-any.whl size=26276 sha256=dc6abec76ca65f5efd370ba0aea2931c05cf969a5a5f9fc7783c9a66e00e7950
#   Stored in directory: /root/.cache/pip/wheels/2b/86/f0/f966ad795a8ba1d9726836d285017e94d56517560bcb95f3fa
# Successfully built cval-lib
# Installing collected packages: cval-lib
# Successfully installed cval-lib-0.0.2.6

# %% [markdown]
# # User guide

# %% [markdown]
# ##### Set your user_api_key

# %%
from cval_lib.connection import CVALConnection
USER_API_KEY = '11a6006a98793bb5086bbf6f6808dd6bd9a706a38ddb36c58a484991263e8535'
cval = CVALConnection(USER_API_KEY)

# %% [markdown]
# ### Dataset
#  > Within the framework of the created system, datasets are spaces in which data for machine learning is stored.
#  Creating a dataset is similar to creating a folder.

# %% [markdown]
# ##### Create dataset

# %%
ds_id = cval.dataset().create(name='on-premise-scheme-ds', description='')
print(ds_id)
# Out:
# a649fd2d-539f-4075-a345-b509d0207c1b

# %% [markdown]
# ##### Update dataset

# %%
ds = cval.dataset()
print(ds.update(ds_id, description='any string data'))
# :NOTE: the dataset can store the state (ds_id)
ds.update(name='sample name')

# %% [markdown]
# ##### Get dataset

# %%
print(ds.get())
# Out:
# dataset_name='sample name' dataset_description='any string data'

# %% [markdown]
# ### :note:
# > A further example of using the library concerns embedding. Since embedding is a large data object and the method of its creation is completely defined by the user, the embedding method works through query schemes (models).

# %% [markdown]
# ### Embeddings
# > Embeddings are vector representations of images obtained using pytorch or any other library

# %% [markdown]
# ##### Create embeddings

# %%
from random import random
import uuid
from cval_lib.models.embedding import ImageEmbeddingModel

img_id_1 = str(uuid.uuid4().hex)
img_id_2 = str(uuid.uuid4().hex)


embeddings = [
 ImageEmbeddingModel(id=img_id_1, image_embedding=list(map(lambda x:random(), range(1000)))),
 ImageEmbeddingModel(id=img_id_2, image_embedding=list(map(lambda x: random(), range(1000)))),
]

print(embeddings)

# %% [markdown]
# ##### Upload & check embeddings

# %%
emb = cval.embedding(ds_id, 'training')
emb.upload_many(embeddings)
print(emb.get_many())
# Out:
# [ImageEmbeddingModel(id='0c9e339e61094b1b8a2881fe22a8b657', image_embedding=[0.182883415626934, 0.9047481631154785, 0.15952746718751476, 0.5379364840688243, 0.742312409878588, 0.9676146839778738, 0.7362478963841561, 0.295557767087549, 0.4101485633591613, 0.3924864011147531, 0.0301985452518726, 0.7330293703094437, 0.8144463202350284, 0.2781351756016267, 0.23451872446797617, 0.5079671474938335, 0.29558339946407974, 0.9770114958535274, 0.162604124882346, 0.7389546636876997, 0.3053664395767991, 0.7234336216735859, 0.9111403520434426, 0.8621022787281892, 0.0025955103453628725, 0.027006082589471125, 0.5211783393785828, 0.27388208347789644, 0.5973122556914633, 0.47789045746939796, 0.4624817395853391, 0.09145944365278846, 0.45900046112012916, 0.1769481609111173, 0.5004675472358109, 0.3946720371164498, 0.6258776601556331, 0.20918200735883252, 0.3590001811651109, 0.6654415892559575, 0.9453418581690588, 0.9068784939125698, 0.10518267179735008, 0.11123993462344262, 0.5374433499797406, 0.17922725419510388, 0.10166899422511577, 0.4782069918746895, 0.29334770923070996, 0.10024825237949764, 0.3066304142686229, 0.9617591897381256, 0.4489637467932026, 0.2872571989880146, 0.639515371011247, 0.5282746754877804, 0.1698161302396335, 0.8243030005798418, 0.45926407952723347, 0.2726907942867479, 0.17508302807874643, 0.9876770965255561, 0.9773795239531954, 0.90960050094696, 0.9134708834939497, 0.9757972835954725, 0.3699399990222777, 0.9331479649719581, 0.5919629147264752, 0.8872096344899628, 0.15513555112237098, 0.3659012433863379, 0.3394468207476885, 0.8156020836796881, 0.20474093269132843, 0.043075718381666794, 0.34467675551378985, 0.058178504468633485, 0.4120045372856147, 0.07515037785140144, 0.625952630055384, 0.9255903457688266, 0.37150228179116307, 0.6856315285900243, 0.3310181561985295, 0.6122755947047556, 0.2612733613950112, 0.9312415581984607, 0.6113269953045009, 0.9126524574554165, 0.9293354911783226, 0.7388088090323275, 0.004584382334380299, 0.5664215890519713, 0.19912299920980958, 0.43718807386317327, 0.6096742919839048, 0.4477923832993037, 0.4337868985525384, 0.5370725920240825, 0.8029937959597823, 0.6715128144989846, 0.7766575337785245, 0.6308021961820053, 0.2317466734238619, 0.4363782490065661, 0.4957727920280012, 0.6591334277477383, 0.17405724518322052, 0.725197738329493, 0.7342282635940041, 0.37267988406610375, 0.3504112205350962, 0.194894051567153, 0.2742841985419733, 0.13367676924129046, 0.8303971320688637, 0.44697388194863286, 0.3946038985883348, 0.08177020167532612, 0.24587450153002677, 0.4817992836561942, 0.2052410081691799, 0.730005118166726, 0.042979045906123226, 0.5208578984194964, 0.4482331519204633, 0.6071005660570592, 0.41119009390465944, 0.4880045112637622, 0.3942192570518205, 0.5846719189250158, 0.0785409575245205, 0.9342708754530662, 0.12595155420762794, 0.4993477706415569, 0.7257374796855421, 0.8109151293801427, 0.5329720741007844, 0.13448970827463436, 0.23073109005943904, 0.38219077354589226, 0.5720771637933193, 0.7484996840081415, 0.6499429354545658, 0.4695082782113219, 0.33335523696196157, 0.09090033859321067, 0.5792354209438991, 0.4336145772648705, 0.07540291242099795, 0.7670893191434645, 0.8806569421931381, 0.2151710012692537, 0.9414288211470996, 0.15181420934378864, 0.9575569842904048, 0.6713044546119692, 0.6980360127015347, 0.30499310980479954, 0.4270393816624064, 0.7278097463612683, 0.12456856975585018, 0.48085015679071064, 0.11406146360492841, 0.13371219883727847, 0.7531022454029526, 0.32559241811674644, 0.9601510916734751, 0.023938543197211337, 0.4917458803601491, 0.3316267883902413, 0.982931623351682, 0.7915408648989459, 0.7605530213258572, 0.0831852909930848, 0.44562254558519776, 0.32041697310716544, 0.2583030291881918, 0.04362575641249644, 0.01760772399660193, 0.09427751529355621, 0.9035409914157754, 0.5197209524619135, 0.6611656127215468, 0.8003884292383421, 0.18613138282724728, 0.785511902835331, 0.8706849688046541, 0.0030048475835000588, 0.06478591794851352, 0.6049164244456307, 0.2776705407979969, 0.54504 ...

# %% [markdown]
# ### :note:
# > The following example is used to invoke active learning

# %% [markdown]
# ### Active learning

# %% [markdown]
# ##### Get predictions data

# %%
from random import random
import uuid
from cval_lib.models.detection import BBoxScores, FramePrediction

# :NOTE: example only
frames_predictions = list(
    map(
        lambda x: FramePrediction(
            frame_id=str(uuid.uuid4().hex),
            predictions=list(
                map(lambda x: BBoxScores(category_id=str(uuid.uuid4()), score=random()), range(10)))
        ),
        range(10)
    )
)
print(frames_predictions)
# Out:
# [FramePrediction(frame_id='ba2172ccd7954ce4a46f77c51bc49ffa', predictions=[BBoxScores(category_id='e516647a-c9dd-4616-b997-dfb7221a8828', score=0.3358898599762583), BBoxScores(category_id='234fb707-2e8e-41c0-9e3e-cf67b51b474e', score=0.1723829358253549), BBoxScores(category_id='ab238fb3-8c46-4fe9-aa0b-deeae0a43b65', score=0.41643044155430076), BBoxScores(category_id='51c3d33e-7d07-4a8b-8346-30131db1586e', score=0.5027018398673647), BBoxScores(category_id='5483370f-455b-48cc-8466-dc17da7e1c34', score=0.15201046997934176), BBoxScores(category_id='0282386d-5498-47e5-a01a-de5c793e4983', score=0.9439275415627925), BBoxScores(category_id='500d881d-e5ea-44d6-b7b2-1b1523de2020', score=0.4425977595353704), BBoxScores(category_id='15f8b559-4aa4-49c8-85f3-81999a0d0f4c', score=0.5283860271236075), BBoxScores(category_id='6f11da20-a2bd-4c84-bd7e-b5bd0cf5a4d7', score=0.957000996827771), BBoxScores(category_id='9b10e0f7-b468-4cf2-9ded-eb81aaf7ef2e', score=0.9040506108597067)]), FramePrediction(frame_id='45503fb99599453eaebef9421a11c79c', predictions=[BBoxScores(category_id='d693bf96-2e70-4a73-952e-17f5fd0fac43', score=0.6212302008573239), BBoxScores(category_id='605cde34-4179-46e9-a348-3c2831376f3b', score=0.9941570977230695), BBoxScores(category_id='9af00a49-7efb-469b-bcd0-20662d713a97', score=0.01670403249128749), BBoxScores(category_id='a1376af5-5129-455f-a72f-2c05fdcd2691', score=0.6639475500997476), BBoxScores(category_id='190109d7-60cf-4edf-9fa0-5411457e3e62', score=0.7679490047859439), BBoxScores(category_id='cd098180-d4f0-4b5b-ba8c-2447da69a719', score=0.25794124330317414), BBoxScores(category_id='9b89458a-b890-400e-aa51-6696599135dd', score=0.539099893980671), BBoxScores(category_id='16c3274b-b04a-41af-b13b-9a50d174164b', score=0.7067256089277179), BBoxScores(category_id='54c375d3-f0c2-4fa8-92d4-5694975720d0', score=0.08374851585470278), BBoxScores(category_id='cb2b59c9-a7db-4397-9f5e-8d5db57f4fd8', score=0.14730628200669793)]), FramePrediction(frame_id='60a4a80caa9643e5b980222d8ce7dd98', predictions=[BBoxScores(category_id='3cf326d4-3236-4d76-8525-1ecebc23f254', score=0.4945628519635088), BBoxScores(category_id='bbaba2d1-143c-4b8b-a9ec-204be5f74b0b', score=0.5840260713051405), BBoxScores(category_id='ec3c4978-f7c2-4934-bb7a-910185c2472a', score=0.43762371744328454), BBoxScores(category_id='f605e816-ad69-4ab0-a121-249612c813c9', score=0.5323455401397356), BBoxScores(category_id='260315f6-e8c3-4c6f-b4b6-169795b1b2e5', score=0.0814820214539359), BBoxScores(category_id='f7c85ed5-357e-4603-80ae-a9891ba07b95', score=0.4705593936504926), BBoxScores(category_id='88af573c-7496-48af-b118-51884f4c1953', score=0.35548775589971526), BBoxScores(category_id='84688eed-92b8-4514-a483-8ac27c746d92', score=0.5222201160661909), BBoxScores(category_id='eedc2bda-3dc6-4481-847a-3cf358c2ba39', score=0.5304412012997456), BBoxScores(category_id='e93f6ad7-8162-41e1-bc24-d58a875b1897', score=0.09903153271063991)]), FramePrediction(frame_id='65dcd6c8adf048b5843ce7674b9cc69f', predictions=[BBoxScores(category_id='bf308342-e18e-47ce-818f-50a0819cc9bf', score=0.9352677166712066), BBoxScores(category_id='4978397b-88f7-46fb-b43b-600534c56394', score=0.3456044826803233), BBoxScores(category_id='c9c23a4d-6dd4-474b-a2ca-61a356cb6aa6', score=0.9478987487631303), BBoxScores(category_id='e8a77ff7-efdb-4f9a-9a54-c5b19158dd6d', score=0.3816566887544266), BBoxScores(category_id='17c6512d-87e6-48e3-bf87-593b656ae2b5', score=0.7037246606405948), BBoxScores(category_id='53fbf6cb-962a-478f-9f56-8286ca22db05', score=0.4222325507083542), BBoxScores(category_id='c286b821-f263-4601-8a44-d76eea6b43d9', score=0.7418614836589945), BBoxScores(category_id='f4e8ed7e-f343-4526-b743-9af19901fed7', score=0.45448191508191027), BBoxScores(category_id='bebd14da-8a6a-4a74-abca-c68846bb4e42', score=0.14132670237404166), BBoxScores(category_id='fbc37656-04fa-4a7b-a0fb-14f39c6216e2', score=0.6034202908987123)]), FramePrediction(frame_id='fb8856b37e894c58a46157005055624b', predictions=[BBoxScores(c ...

# %% [markdown]
# ##### Construct config

# %%
from cval_lib.models.detection import DetectionSamplingOnPremise
request = DetectionSamplingOnPremise(
 num_of_samples=200,
 bbox_selection_policy='min',
 selection_strategy='margin',
 sort_strategy='ascending',
 frames=frames_predictions,
)

# %% [markdown]
# ##### Run active learning

# %%
emb = cval.detection()
print(emb.on_premise_sampling(request))

# %% [markdown]
# ###:note:
# > The following method is most relevant when we are dealing with long-term tasks and, accordingly, with asynchronous interaction.

# %% [markdown]
# ### Polling
# > refers to actively sampling the status of an external device by a client program as a synchronous activity.

# %%
import uuid
from random import random
from time import sleep

frames_predictions = list(
        map(
            lambda x: FramePrediction(
                frame_id=str(uuid.uuid4().hex),
                predictions=list(map(lambda _: BBoxScores(category_id=str(uuid.uuid4()), score=random()), range(20)))
            ),
            range(10000)
        )
    )

request = DetectionSamplingOnPremise(
        num_of_samples=200,
        bbox_selection_policy='min',
        selection_strategy='margin',
        sort_strategy='ascending',
        frames=frames_predictions,
    )

emb = cval.detection()
print(emb.on_premise_sampling(request))

result = None
sleep_sec = 1
while result is None:
    result = emb.result.get().result
    print(f'Polling... {sleep_sec} s')
    sleep(sleep_sec)
    sleep_sec *= 2
print(result)
# Out:
# result_id='8a7602f2-62c3-4657-b474-db7896d30995' dataset_id=None time_start=1688720424.7429168 time_end=None type_of_task='detection' action='sampling' weights=None result=None
# Polling... 1 s
# Polling... 2 s
# [['82f0ff8a36174fb78f89b4d7bbfc9904', 5.560923985736821e-07], ['a18c3fb0d5514d75a5ddbe108b1ac74e', 9.38554847174089e-07], ['ca616c71ca4c49a28e298a371cdca4cf', 4.008784241671393e-06], ['099ce1db73c64083b87d05bf9b3ab4ae', 5.391039287427901e-06], ['50c831d82cc54eee870a21cd1eef9ea9', 9.009528112224885e-06], ['7e3531c801f648b8a3b20d3a87a8e53b', 1.699338077210122e-05], ['858d0d800c734a7e88c48b105e4476e4', 2.5503062988985192e-05], ['cc486c73d3884fecae986d0921c82909', 3.384238730164135e-05], ['0e5c1f7b7a9b41d9ae8f2c9f5e3067a6', 3.547784738722193e-05], ['badc089c4e16435fa6069e4a3e7949ad', 5.019064892031189e-05], ['07c453f7815e4892a80b2d76560c4bc2', 5.3094090874949984e-05], ['941d8105ab6845c490412fba58281857', 5.319552177152076e-05], ['0395a1b650be4f6382e50383f2a6b68b', 5.9454336810649266e-05], ['bd36940ecca14167b564df718d45a43b', 6.298765797518868e-05], ['4a9cdb2e4f524e43a175e4c35fdaf5b3', 7.075377589282894e-05], ['5ca5928e06bd4319bda21e0153299ba7', 7.877962282942796e-05], ['f4eb2beb035844fdb42a72d15a9c8778', 8.06164187168168e-05], ['bc56d7eeca1b4e1d9dba10e5e0a2cf2f', 8.71607077734815e-05], ['5beb0f041a9b43fbb75ca06d24dfe8a2', 0.00010424975422451688], ['7248d5f3f6f544ec836855d1135acdbe', 0.00012041718175903604], ['13b662714ed34684b692604e78c4e2db', 0.00012433824152457973], ['1f483b3b2a184af28bcdad26eb6730ba', 0.0001310087031249907], ['b0e6c82566aa4b00974b5d4201f1a810', 0.00015518552030835409], ['7e90529275c046a6bb8181ee2bb6ece7', 0.00017212273855160554], ['732847478ced4066bcd22e0e9f9e9d9c', 0.00017239840407201612], ['e1e6f48294474f30b87ab1e8eea700ee', 0.00017519027010304278], ['cc75503476cb4f1bba72f825cbf79949', 0.00017898851819397876], ['fc5fad39ace445fc9c531f11e9de7d19', 0.0001817145773119755], ['5f081bf091254740b9b629e0683e024b', 0.0001923703853932146], ['cbbd7c19ab7d43fbac3d4c63271ed8b4', 0.00020776623993312704], ['b8b788b417aa402aa9c37787d76aa29d', 0.00020820025387768837], ['b2e58aca5fb642c0ab39b811b065dcdb', 0.00020833930471564344], ['769b7edf084a45fa8843af68d86d90f2', 0.00022063252088488916], ['6fda7f96511d4a7298ba59708a541f19', 0.00022064571531110744], ['d30966751d144cbd96892743d8f823fa', 0.00022083894379676394], ['56eb2f1c3f8848c6beb38108d08b7585', 0.00022672968501180613], ['100a6a289af44cfe90a38527b91da303', 0.00023047828565747608], ['68672c16032d4c529a53e4e7c5e6dee5', 0.0002546051904837032], ['0ec136cffcc84013b1aeea8ce6094634', 0.00025654920505968626], ['a435cf8f1e6a4dc0803c81994f739498', 0.0002691834442478669], ['db946b08be6b4e1890c4702ea8480b8b', 0.00027925408247408967], ['b369ad6b6cac4bab881fc2732ba51113', 0.0002891898544821192], ['6b64fde3b9094bee95969cfe66e12734', 0.0002894012367693488], ['6a1920e54f424de5bfd4fa9d140038c7', 0.00029955009679305533], ['3d18bc2a55a8467a9d5ec3fbdc56caec', 0.00030476917012633997], ['f3a71e0b425b4b01be87f161503f183d', 0.000310655014528205], ['b81ac26e09414489bcf262cb632ba17c', 0.0003136302651955969], ['1c21d0bc38d64618aa7eadd39b7bb9f2', 0.0003228261723942083], ['62e9bd6af4404cb486c9ea8255d4502e', 0.00032528883921645324], ['4a9069d999f54562886693de93d5e76d', 0.0003318742610725067], ['fa580cd745b0427f8537edf5793c094b', 0.0003356168767012502], ['8b6ad6848e1b4b1eb1e6209084e6c345', 0.00033775121646417716], ['f2c86f4d0d2441488f43f7d8c67408e2', 0.00036139600945950257], ['eaae9097f0d240e8822754f36f0dfaaf', 0.00036481780085573234], ['44e7b2eff4e548b69254880879e9a026', 0.0003659269175204649], ['efa19f5f7e2644d29df7847993ec4abf', 0.0003668541227750399], ['74c5249685914b869da3dcb9818b1a22', 0.00036748098833205844], ['5638ff8f37f948faa5c3750d054944d0', 0.00036955042267927674], ['c78286685846428aaec1a4f08c0a6b18', 0.00037113722345161193], ['f763319747364dbaae48e92473a99aa7', 0.0003726008269466785], ['67ba5a16f0784b83a208513c7da50692', 0.0003729338110074476], ['dc74c32d5ce54fb4941a348fcd070a79', 0.0003731405640807761], ['19ef9a0360164e46bf5ade9a88b6a482', 0.00037793859075008207], ['6d9167e6d885499cb3eff556fe385d1a', 0.0003889709303299682], ['b7eae96e5ee249a3b167875d75800d48', 0.00038928292437678813], ['6b21 ...
